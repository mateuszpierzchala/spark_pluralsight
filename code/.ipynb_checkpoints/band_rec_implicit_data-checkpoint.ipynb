# %%
from pyspark.sql import SparkSession

spark = SparkSession\
        .builder\
        .appName('użycie implicit data do rekomendacji zespołów na last.fm')\
        .getOrCreate()

rawData = spark.read.format('csv').\
option('delimiter', '\t').\
option('header','true').\
load('../datasets/lastfm/user_artists.dat')

rawData.toPandas().head()
# Out:
#   userID artistID weight
# 0      2       51  13883
# 1      2       52  11690
# 2      2       53  11351
# 3      2       54  10300
# 4      2       55   8983

# %%
from pyspark.sql.functions import col

dataset  = rawData.select(col('userID').cast('int'),
                          col('artistID').cast('int'),
                          col('weight').cast('int')
                         )

dataset.toPandas().head()
# Out:
#    userID  artistID  weight
# 0       2        51   13883
# 1       2        52   11690
# 2       2        53   11351
# 3       2        54   10300
# 4       2        55    8983

# %%
dataset.select('weight').describe().toPandas()
# Out:
#   summary              weight
# 0   count               92834
# 1    mean   745.2439300256372
# 2  stddev  3751.3220803876798
# 3     min                   1
# 4     max              352698

# %%
### Standaryzacja: skalowana wart = (wartosc - srednia)/odchylenie std.

# %%
from pyspark.sql.functions import stddev, mean, col

df= dataset.select(mean('weight').alias('mean_weight'),
                  stddev('weight').alias('stddev_weight'))\
            .crossJoin(dataset)\
            .withColumn('weight_scaled',
                       (col('weight')-col('mean_weight')) / col('stddev_weight'))
df.toPandas().head()
# Out:
#    mean_weight  stddev_weight  userID  artistID  weight  weight_scaled
# 0    745.24393     3751.32208       2        51   13883       3.502167
# 1    745.24393     3751.32208       2        52   11690       2.917573
# 2    745.24393     3751.32208       2        53   11351       2.827205
# 3    745.24393     3751.32208       2        54   10300       2.547037
# 4    745.24393     3751.32208       2        55    8983       2.195961

# %%
(trainingData, testData) = df.randomSplit([0.8 , 0.2])

# %%
from pyspark.ml.recommendation import ALS

als = ALS(maxIter = 10,
         regParam = 0.1,
         userCol='userID',
         itemCol = 'artistID',
         implicitPrefs = True, ###tu sie dzieje magia
         ratingCol = 'weight_scaled',
          coldStartStrategy = 'drop'
         )

model = als.fit(trainingData)

# %%
predictions = model.transform(testData)
predictions.toPandas().head()
# Out:
#    mean_weight  stddev_weight  userID  artistID  weight  weight_scaled  \
# 0    745.24393     3751.32208    1280       463     316      -0.114425
# 1    745.24393     3751.32208    2055       463     863       0.031391
# 2    745.24393     3751.32208     592       463     544      -0.053646
# 3    745.24393     3751.32208      11       463    1235       0.130556
# 4    745.24393     3751.32208    1456       471     825       0.021261
#
#    prediction
# 0    0.009873
# 1    0.002418
# 2    0.013848
# 3   -0.000658
# 4    0.004051

# %%
predictionsPandas=predictions.select('weight_scaled','prediction').toPandas()
predictionsPandas.describe()
# Out:
#        weight_scaled    prediction
# count   16104.000000  16104.000000
# mean        0.011152      0.041971
# std         1.259393      0.099290
# min        -0.198395     -0.402290
# 25%        -0.168539      0.000000
# 50%        -0.126954      0.002338
# 75%        -0.026989      0.034803
# max        93.820991      0.968772

# %%
artistData = spark.read.format('csv').\
option('delimiter', '\t').\
option('header','true').\
load('../datasets/lastfm/artists.dat')

artistData.toPandas().head()
# Out:
#   id               name                                         url  \
# 0  1       MALICE MIZER       http://www.last.fm/music/MALICE+MIZER
# 1  2    Diary of Dreams    http://www.last.fm/music/Diary+of+Dreams
# 2  3  Carpathian Forest  http://www.last.fm/music/Carpathian+Forest
# 3  4       Moi dix Mois       http://www.last.fm/music/Moi+dix+Mois
# 4  5        Bella Morte        http://www.last.fm/music/Bella+Morte
#
#                                           pictureURL
# 0    http://userserve-ak.last.fm/serve/252/10808.jpg
# 1  http://userserve-ak.last.fm/serve/252/3052066.jpg
# 2  http://userserve-ak.last.fm/serve/252/40222717...
# 3  http://userserve-ak.last.fm/serve/252/54697835...
# 4  http://userserve-ak.last.fm/serve/252/14789013...

# %%
from pyspark.sql.types import IntegerType

def getRecommendationsForUser(userId, numRecs):
    
    usersDF = spark.createDataFrame([userId], IntegerType()).toDF('userId')
    userRecs = model.recommendForUserSubset(usersDF, numRecs)
    
    artistsList = userRecs.collect()[0].recommendations
    artistsDF = spark.createDataFrame(artistsList)
    
    recommendedArtists = artistData.join(artistsDF, artistData.id == artistsDF.artistID).orderBy('rating', ascending = False).select('name', 'url', 'rating')
    return recommendedArtists

# %%
getRecommendationsForUser(939,10).toPandas()
# Out:
#                       name                                               url  \
# 0                 Paramore                 http://www.last.fm/music/Paramore
# 1       30 Seconds to Mars       http://www.last.fm/music/30+Seconds+to+Mars
# 2      My Chemical Romance      http://www.last.fm/music/My+Chemical+Romance
# 3             All Time Low             http://www.last.fm/music/All+Time+Low
# 4        Avenged Sevenfold        http://www.last.fm/music/Avenged+Sevenfold
# 5              Linkin Park              http://www.last.fm/music/Linkin+Park
# 6              Evanescence              http://www.last.fm/music/Evanescence
# 7                 The Used                 http://www.last.fm/music/The+Used
# 8      Panic! At the Disco    http://www.last.fm/music/Panic%21+At+the+Disco
# 9  Bullet for My Valentine  http://www.last.fm/music/Bullet+for+My+Valentine
#
#      rating
# 0  0.415596
# 1  0.342345
# 2  0.304962
# 3  0.292554
# 4  0.285320
# 5  0.266710
# 6  0.199473
# 7  0.162944
# 8  0.162387
# 9  0.161737

# %%
userArtistRaw = dataset.filter(dataset.userID == 939)

userArtistsInfo = artistData.join(userArtistRaw,
                                artistData.id==userArtistRaw.artistID)\
                                .orderBy('weight', ascending = False)\
                                .select('name', 'weight')

userArtistsInfo.toPandas()
# Out:
#                          name  weight
# 0           Avenged Sevenfold   10595
# 1          30 Seconds to Mars    1646
# 2              A Skylit Drive    1603
# 3             Sonic Syndicate    1439
# 4                    Paramore    1184
# 5        Funeral for a Friend    1127
# 6             Light This City    1125
# 7         My Chemical Romance    1055
# 8              As I Lay Dying    1047
# 9               Dead by April    1044
# 10    Bullet for My Valentine    1005
# 11            Brandnew Sunset     949
# 12           We Are The Ocean     938
# 13               Shadows Fall     923
# 14           All That Remains     873
# 15               Lostprophets     863
# 16          A Day to Remember     827
# 17                        AFI     827
# 18               Mariah Carey     803
# 19                 Hey Monday     766
# 20                 Young Guns     738
# 21       Bring Me The Horizon     720
# 22                    Incubus     717
# 23             In This Moment     638
# 24        Theory of a Deadman     630
# 25                Silly Fools     595
# 26                      Epica     590
# 27                VersaEmerge     540
# 28         Coheed and Cambria     537
# 29                     Saosin     517
# 30                      Creed     515
# 31  The Dillinger Escape Plan     510
# 32          Story of the Year     510
# 33                 Yellowcard     497
# 34                   Slipknot     495
# 35    I Killed the Prom Queen     478
# 36                 Pixie Lott     474
# 37          Crucified Barbara     472
# 38                 Stone Sour     456
# 39            Escape The Fate     450
# 40                Heartsounds     449
# 41                    Volbeat     433
# 42          Asking Alexandria     412
# 43                      Evita     395
# 44                 Arch Enemy     392
# 45      The Syncope Threshold     370
# 46                Keri Hilson     366
# 47           August Burns Red     359
# 48               Taylor Swift     346
# 49            Michael Jackson     341

# %%
getRecommendationsForUser(1726,10).toPandas()
# Out:
#                  name                                          url    rating
# 0      Britney Spears      http://www.last.fm/music/Britney+Spears  0.750255
# 1  Christina Aguilera  http://www.last.fm/music/Christina+Aguilera  0.603080
# 2             Rihanna             http://www.last.fm/music/Rihanna  0.401273
# 3           Lady Gaga           http://www.last.fm/music/Lady+Gaga  0.365778
# 4             Beyoncé        http://www.last.fm/music/Beyonc%C3%A9  0.296125
# 5             Madonna             http://www.last.fm/music/Madonna  0.286955
# 6        Mariah Carey        http://www.last.fm/music/Mariah+Carey  0.273625
# 7          Katy Perry          http://www.last.fm/music/Katy+Perry  0.233365
# 8       Kylie Minogue       http://www.last.fm/music/Kylie+Minogue  0.212886
# 9      Jennifer Lopez      http://www.last.fm/music/Jennifer+Lopez  0.188941

# %%
userArtistRaw = dataset.filter(dataset.userID == 1726)

userArtistsInfo = artistData.join(userArtistRaw,
                                artistData.id==userArtistRaw.artistID)\
                                .orderBy('weight', ascending = False)\
                                .select('name', 'weight')

userArtistsInfo.toPandas()
# Out:
#                   name  weight
# 0       Britney Spears   13804
# 1   Christina Aguilera    1396
# 2              Rihanna    1056
# 3              Shakira    1027
# 4           Katy Perry     651
# 5              Beyoncé     544
# 6            Lady Gaga     517
# 7          Cheryl Cole     478
# 8         David Guetta     466
# 9                Ke$ha     446
# 10         Nicki Minaj     443
# 11               Usher     420
# 12             Madonna     392
# 13          Kanye West     364
# 14              M.I.A.     300
# 15              Eminem     294
# 16               Ciara     284
# 17       Janet Jackson     252
# 18         Danity Kane     239
# 19  The Pussycat Dolls     224
# 20     Black Eyed Peas     217
# 21           Timbaland     194
# 22      Jennifer Lopez     191
# 23      Kelly Clarkson     190
# 24     Destiny's Child     170
# 25        Mariah Carey     169
# 26      Ashlee Simpson     164
# 27        Adam Lambert     163
# 28         Chris Brown     150
# 29                P!nk     146
# 30        Gwen Stefani     145
# 31        Brooke Hogan     142
# 32        Simon Curtis     138
# 33     Michael Jackson     132
# 34            Maroon 5     131
# 35          Lil' Wayne     127
# 36        Robin Thicke     125
# 37               Robyn     117
# 38         Miley Cyrus     112
# 39       Missy Elliott     112
# 40    Enrique Iglesias     110
# 41              *NSYNC     101
# 42           Taio Cruz      95
# 43            Jessie J      95
# 44    Leighton Meester      94
# 45       Kylie Minogue      93
# 46                T.I.      87
# 47   Far East Movement      86
# 48            Ludacris      85
# 49       Lindsay Lohan      81
